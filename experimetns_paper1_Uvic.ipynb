# %% [markdown]
# Import google drive

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# clone my reository to my google drive

# %%
#import os
# Create a new folder
#folder_path = '/content/drive/MyDrive/uvic_paper1'
#os.makedirs(folder_path, exist_ok=True)
#!rm -rf /content/drive/MyDrive/uvic_paper1
# !git clone https://github.com/s2kamyab/cmp_limited_data.git /content/drive/MyDrive/uvic_paper1
# Out:
# Cloning into '/content/drive/MyDrive/uvic_paper1'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 6 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (6/6), done.

# %%
# !cp /content/drive/MyDrive/Colab Notebooks/experimetns_paper1_Uvic.ipynb /content/drive/MyDrive/uvic_paper1/experimetns_paper1_Uvic.ipynb
# Out:
# cp: target '/content/drive/MyDrive/uvic_paper1/experimetns_paper1_Uvic.ipynb' is not a directory

# %%
# %cd /content/drive/MyDrive/uvic_paper1
# %ls
# Out:
# /content/drive/MyDrive/uvic_paper1
# README.md

# %% [markdown]
# Install dependencies

# %%
# !pip install pandas numpy matplotlib statsmodels
# !pip install scikit-learn
#!pip install tensorflow  # For TensorFlow
# !pip install torch torchvision torchaudio  # For PyTorch

# %% [markdown]
# Load the M4 Dataset
#
# The M4 dataset can be downloaded from the M4 competition website. Use the following code to download and load the dataset:

# %%
#!git clone https://github.com/Mcompetitions/M4-methods.git
# %cd M4-methods/Dataset/Train
import pandas as pd
m4_data = pd.read_excel('Monthly-train.csv')
# Out:
# /content/M4-methods/Dataset/Train
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-f606f9b545e4> in <cell line: 4>()
#       2 get_ipython().run_line_magic('cd', 'M4-methods/Dataset/Train')
#       3 import pandas as pd
# ----> 4 m4_data = pd.read_excel('Monthly-train.csv')
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     502     if not isinstance(io, ExcelFile):
#     503         should_close = True
# --> 504         io = ExcelFile(
#     505             io,
#     506             storage_options=storage_options,
#
# ...

# %% [markdown]
# Explore the Data

# %%
# Check the keys (sheets) in the dataset
print(m4_data.keys())

# Load one of the sheets, for example, the "Monthly" series
monthly_data = m4_data['Monthly']
print(monthly_data.head())

# %% [markdown]
# clone M4 repo

# %% [markdown]
# Clone Moment dataset

# %%
#!git clone https://huggingface.co/datasets/AutonLab/Timeseries-PILE
# Out:
# Cloning into 'Timeseries-PILE'...
# remote: Enumerating objects: 2635, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 2635 (delta 9), reused 0 (delta 0), pack-reused 2615 (from 1)
# Receiving objects: 100% (2635/2635), 400.49 MiB | 11.72 MiB/s, done.
# Resolving deltas: 100% (414/414), done.
# Updating files: 100% (2441/2441), done.
# Filtering content: 100% (62/62), 6.37 GiB | 39.40 MiB/s, done.

# %% [markdown]
# Install MOMENT model

# %%
# !pip install git+https://github.com/moment-timeseries-foundation-model/moment.git
# Out:
# ...
#   Cloning https://github.com/moment-timeseries-foundation-model/moment.git to /tmp/pip-req-build-5jaud4hj
#   Running command git clone --filter=blob:none --quiet https://github.com/moment-timeseries-foundation-model/moment.git /tmp/pip-req-build-5jaud4hj
#   Resolved https://github.com/moment-timeseries-foundation-model/moment.git to commit 1d7f7bd73825a9c6c5e660a832f186f58516d186
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
